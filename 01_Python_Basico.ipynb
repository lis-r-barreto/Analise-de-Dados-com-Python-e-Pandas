# %% [markdown]
# <a href="https://colab.research.google.com/github/lis-r-barreto/analise-de-dados-com-python-e-pandas/blob/main/01_Python_Basico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Básico**

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %%
print('Estou aprendendo Python')
# Out:
# Estou aprendendo Python

# %%
'Estou aprendendo Python'
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
# Esse é um comentário em Python

# %%
2 * 2 # Operação produto
# Out:
# 4

# %%
10 / 2 # Operação divisão
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
frase = 'Python para Análise de Dados'

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10] # a notação de fatiamento é inclusiva à esquerda, mas não à direita
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a Análise de Dados'

# %%
frase[:17]
# Out:
# 'Python para Análi'

# %%
frase.count('Dados')
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace('Python', 'R')
# Out:
# 'R para Análise de Dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'
